# %%
dataset = pd.read_csv(r"D:\true_car_project_full.csv")
dataset
# Out:
#               Id  Price  Year  Mileage            City State  \
# 0              1  16472  2015    18681  Jefferson City    MO
# 1              2  15749  2015    27592        Highland    IN
# 2              3  16998  2015    13650           Boone    NC
# 3              4  15777  2015    25195     New Orleans    LA
# 4              5  16784  2015    22800       Las Vegas    NV
# ...          ...    ...   ...      ...             ...   ...
# 1048570  1048571  16995  2015    27095        Honolulu    HI
# 1048571  1048572  20491  2014    77590        Franklin    WI
# 1048572  1048573  19355  2014    34554     King George    VA
# 1048573  1048574  17173  2014    61115          Conroe    TX
# 1048574  1048575  18097  2014    40625           Macon    GA
#
#                 City State                Vin    Make              Model  \
# 0        Jefferson City MO  KL4CJBSBXFB267643   Buick  EncoreConvenience
# 1              Highland IN  KL4CJASB5FB245057   Buick          EncoreFWD
# ...

# %%
print(len(dataset['Region'].unique()))
# Out:
# 6

# %%
dataset.groupby('Region')['Price'].median().plot()
plt.xlabel('Region')
plt.ylabel('Median Car Price')
plt.title("Car Price vs Region")
# Out:
# Text(0.5, 1.0, 'Car Price vs Year')

# %%
sns.boxplot(x = dataset['Region'],y = dataset['Price'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Price'>

# %%
dataset.groupby('Region')['Mileage'].median().plot()
plt.xlabel('Region')
plt.ylabel('Median Car Mileage')
plt.title("Car Mileage vs Region")
# Out:
# Text(0.5, 1.0, 'Car Mileage vs Region')
